# %% [markdown]
# ## 后台将Excel数据导入到数据库 ##

# %% [markdown]
# 说明:直接在后端将Excel导入到数据库中,主要是在项目初始化时。用户日常操作时需要导入的数据需要从前端操作。

# %%
import pandas as pd
from sqlalchemy import create_engine
#连接数据库，这里使用的是sqlite
engine = create_engine('sqlite:///app.db', echo=False)

# %% [markdown]
# ### 导入学校数据 ###

# %%
#读取excel
filename = "school.xlsx"
df = pd.read_excel(filename,encoding='utf8',sheet_name='Sheet1')  #指定sheet的名称，默认是第一个
df
# Out:
#          fullname       name  organizationunit_id         label
# 0     通州区教育人才交流中心     人才交流中心                    3          局直单位
# 1       通州区教师发展中心     教师发展中心                    3          局直单位
# 2     通州区招生委员会办公室        招生办                    3          局直单位
# 3          通州区审计办   审计办、资助中心                    3          局直单位
# 4      通州区勤工俭学办公室        勤工办                    3          局直单位
# 5      通州区校舍管理办公室        校舍办                    3          局直单位
# 6         通州区青少年宫       青少年宫                    3          局直单位
# 7         通州区教育工会       教育工会                    3          局直单位
# 8      通州区教育技术装备室        装备室                    3          局直单位
# 9      通州区校舍安全办公室        校安办                    3          局直单位
# 10      江苏省通州高级中学     通州高级中学                    4     区管局直学校,高中
# 11        通州区金沙中学       金沙中学                    4     区管局直学校,高中
# 12      江苏省西亭高级中学     西亭高级中学                    4     区管局直学校,高中
# 13      江苏省平潮高级中学     平潮高级中学                    4     区管局直学校,高中
# 14        通州区二甲中学       二甲中学                    4     区管局直学校,初中
# 15        通州区二窎中学       二窎中学                    4     区管局直学校,初中
# 16        通州区石港中学       石港中学                    4     区管局直学校,初中
# 17        通州区刘桥中学       刘桥中学                    4     区管局直学校,初中
# 18        通州区兴仁中学       兴仁中学                    4     区管局直学校,初中
# 19        通州区姜灶中学       姜灶中学                    4     区管局直学校,初中
# 20        通州区通海中学       通海中学                    4     区管局直学校,初中
# 21    江苏省通州中等专业学校       通州中专                    4     区管局直学校,职中
# 22        通州区育才中学       育才中学                    4     区管局直学校,初中
# 23        通州区实验中学       实验中学                    4     区管局直学校,初中
# 24      通州区平潮实验初中     平潮实验初中                    4     区管局直学校,初中
# 25        通州区实验小学       实验小学                    4     区管局直学校,小学
# 26        通州区通州小学       通州小学                    4     区管局直学校,小学
# 27        南通高新区小学    南通高新区小学                    4     区管局直学校,小学
# 28      通州区特殊教育学校     特殊教育学校                    4     区管局直学校,特教
# 29     通州区乒乓球运动学校    乒乓球运动学校                    4  区管局直学校,乒乓球运动
# ..            ...        ...                  ...           ...
# 135       通州区刘桥小学       刘桥小学                    4    通西片,刘桥镇,小学
# 136      通州区刘桥幼儿园      刘桥幼儿园                    4   通西片,刘桥镇,幼儿园
# 137      通州区平东成人校      平东成人校                    4   通西片,刘桥镇,成人校
# 138       通州区英雄小学       英雄小学                    4    通西片,刘桥镇,小学
# 139      通州区英雄幼儿园      英雄幼儿园                    4   通西片,刘桥镇,幼儿园
# 140       通州区新联中学       新联中学                    4    通西片,刘桥镇,初中
# 141       通州区新联小学       新联小学                    4    通西片,刘桥镇,小学
# 142      通州区新联幼儿园      新联幼儿园                    4   通西片,刘桥镇,幼儿园
# 143    通州区通南教育督导组    通南教育督导组                    3       通南片,督导组
# 144     通州区锡通园区小学     锡通园区小学                    4   通南片,张芝山镇,小学
# 145     通州区张芝山成人校     张芝山成人校                    4  通南片,张芝山镇,成人校
# 146      通州区星河幼儿园      星河幼儿园                    4  通南片,张芝山镇,幼儿园
# 147     通州区张芝山幼儿园     张芝山幼儿园                    4  通南片,张芝山镇,幼儿园
# 148      通州区红星幼儿园      红星幼儿园                    4  通南片,张芝山镇,幼儿园
# 149       通州区南兴小学       南兴小学                    4   通南片,张芝山镇,小学
# 150      通州区南兴幼儿园      南兴幼儿园                    4  通南片,张芝山镇,幼儿园
# 151      通州区高桥幼儿园      高桥幼儿园                    4  通南片,张芝山镇,幼儿园
# 152       通州区川港中学       川港中学                    4    通南片,川姜镇,初中
# 153  通州区川姜镇社区教育中心  川姜镇社区教育中心                    4   通南片,川姜镇,成人校
# 154       通州区川港小学       川港小学                    4    通南片,川姜镇,小学
# 155    通州区川港大地幼儿园    川港大地幼儿园                    4   通南片,川姜镇,幼儿园
# 156      通州区家纺城小学      家纺城小学                    4    通南片,川姜镇,小学
# 157     通州区家纺城幼儿园     家纺城幼儿园                    4   通南片,川姜镇,幼儿园
# 158       通州区姜灶小学       姜灶小学                    4    通南片,川姜镇,小学
# 159      通州区姜灶幼儿园      姜灶幼儿园                    4   通南片,川姜镇,幼儿园
# 160       通州区先锋初中       先锋初中                    4   通南片,先锋街道,初中
# 161      通州区先锋成人校      先锋成人校                    4  通南片,先锋街道,成人校
# 162       通州区先锋小学       先锋小学                    4   通南片,先锋街道,小学
# 163      通州区先锋幼儿园      先锋幼儿园                    4  通南片,先锋街道,幼儿园
# 164      通州区志新幼儿园      志新幼儿园                    4  通南片,先锋街道,幼儿园
#
# [165 rows x 4 columns]

# %%
#插入到数据库，注意这里的选项是如果表存在，则先删除表，再插入，如果你只想追加，请修改if_exists='append'

df.to_sql('schools',con=engine,if_exists='append',index=True)

# %%
for i in list(df.columns):
    catagoray[i] = []
    for item in df[i].fillna(0):    #将值为NaN用零填充
        if item != 0:
            catagoray.get(i).append(item)
#catagoray数据格式为：{'列名' : ['值1', '值2'，'值2']}


pd.DataFrame(catagoray).to_sql('talbe_name',con=engine,if_exists='append',index=True)
engine.execute("SELECT * FROM talbe_name")    #查询

##扩展，如果在数据库中插入数据为列表格式，需要在创建DataFrame对象的时候指定列名
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

filename = "运营平台商品清单模板_新版0712.xlsx"
catagoray = []
#读取excel
df = pd.read_excel(filename,encoding='utf8',sheet_name='商品类目')   #指定sheet的名称，默认是第一个
data = np.array(df)
for item in data:
    catagoray.append(list(item))

engine = create_engine('mysql+pymysql://user:password@mysql_ip:3306/database', echo=False)
pd.DataFrame(catagoray,columns=['列1','列2','列3']).to_sql('talbe_name',con=engine,if_exists='append',index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bf17e65cc8df> in <module>()
#       1 for i in list(df.columns):
# ----> 2     catagoray[i] = []
#       3     for item in df[i].fillna(0):    #将值为NaN用零填充
#       4         if item != 0:
#       5             catagoray.get(i).append(item)
#
# NameError: name 'catagoray' is not defined
